# %% [markdown]
# # LGM task - 2 [Pencil sketch using python]

# %% [markdown]
# ## Importing libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the image

# %%
image = cv2.imread(r'C:\Users\Roj Kanwar\Downloads\puppy4.jpg')

# %%
plt.figure(figsize=(12,12))
plt.imshow(image)
plt.axis("off")
plt.title("RGB image")
plt.show()

# %% [markdown]
# ## Converting an image into gray_scale image

# %%
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(12,12))
plt.imshow(img_gray,cmap = 'gray')
plt.axis("off")
plt.title("RGB image")
plt.show()

# %% [markdown]
# ## Inverting the image

# %%
img_smoothing = cv2.GaussianBlur(img_invert,(21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(12,12))
plt.imshow(img_smoothing)
plt.axis("off")
plt.title("Smoothing image")
plt.show()

# %% [markdown]
# ## Smoothing the image

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(12,12))
plt.imshow(img_invert)
plt.axis("off")
plt.title("inverted image")
plt.show()

# %% [markdown]
# ## Obtaining the final sketch

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)
final_img = dodgeV2(img_gray, img_smoothing)
plt.figure(figsize=(12,12))
plt.imshow(final_img,cmap = 'gray')
plt.axis("off")
plt.title("final image")
plt.show()

# %% [markdown]
# ## plotting both (RBG AND PENCIL SKETCH) togrther

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.imshow(image)
plt.axis("off")
plt.title("RBG image")
plt.subplot(1,2,2)
plt.imshow(final_img,cmap = 'gray')
plt.axis("off")
plt.title("final image")
# Out:
# Text(0.5, 1.0, 'final image')
